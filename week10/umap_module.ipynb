# %% [markdown]
# # Imports

# %%
# !pip install umap-learn
# Out:
# Collecting umap-learn
#   Using cached umap-learn-0.5.0.tar.gz (81 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\tayma\anaconda3\envs\py37\lib\site-packages (from umap-learn) (1.17.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\tayma\anaconda3\envs\py37\lib\site-packages (from umap-learn) (0.23.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\tayma\anaconda3\envs\py37\lib\site-packages (from umap-learn) (1.5.2)
# Requirement already satisfied: numba>=0.49 in c:\users\tayma\anaconda3\envs\py37\lib\site-packages (from umap-learn) (0.51.2)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.1.tar.gz (1.1 MB)
# Requirement already satisfied: joblib>=0.11 in c:\users\tayma\anaconda3\envs\py37\lib\site-packages (from scikit-learn>=0.22->umap-learn) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tayma\anaconda3\envs\py37\lib\site-packages (from scikit-learn>=0.22->umap-learn) (2.1.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\tayma\anaconda3\envs\py37\lib\site-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\tayma\anaconda3\envs\py37\lib\site-packages (from numba>=0.49->umap-learn) (50.3.1.post20201107)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.0-py3-none-any.whl size=76338 sha256=9ee41d26b7584fdd25ae127bf982c823478f8d8337cb3fd2115634f28885a0fc
#   Stored in directory: c:\users\tayma\appdata\local\pip\cache\wheels\ae\d7\10\0b474d56359c3caf8472e626dd0fd2dcc33d7a011f0458ac7d
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.1-py3-none-any.whl size=48610 sha256=12331ea056b2eea6134a8596887914dca700acfcd217adddd78caf16d94bec16
#   Stored in directory: c:\users\tayma\appdata\local\pip\cache\wheels\e5\21\ae\4860d52fcf914e4fada06cd3dcc917efcc903d26250753f47f
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.1 umap-learn-0.5.0

# %%
# %reload_ext nb_black
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import plotly
import seaborn as sns

# %matplotlib inline
from scipy import stats

plt.style.use(["dark_background"])
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_openml
import time
import umap
# Out:
# C:\Users\tayma\anaconda3\envs\py37\lib\site-packages\umap\__init__.py:9: UserWarning: Tensorflow not installed; ParametricUMAP will be unavailable
#   warn("Tensorflow not installed; ParametricUMAP will be unavailable")

# %%
# We load the MNIST dataset below
mnist = fetch_openml("mnist_784", version=1, cache=True)

np.random.seed(42)

indices = np.random.choice(70000, 10000)
X = mnist.data[indices] / 255.0
y = mnist.target[indices]

print(X.shape, y.shape)
# Out:
# (10000, 784) (10000,)

# %%
time_start = time.time()

umap_results = umap.UMAP(
    #     n_neighbors=5,
    #     min_dist=0.3,
    #     metric="correlation"
).fit_transform(X)

print("UMAP done! Time elapsed: {} seconds".format(time.time() - time_start))

plt.figure(figsize=(10, 5))
colours = ["r", "b", "g", "c", "m", "y", "k", "r", "burlywood", "chartreuse"]
for i in range(umap_results.shape[0]):
    plt.text(
        umap_results[i, 0],
        umap_results[i, 1],
        y[i],
        color=colours[int(y[i])],
        fontdict={"weight": "bold", "size": 50},
    )

plt.xticks([])
plt.yticks([])
plt.axis("off")
plt.show()
# Out:
# UMAP done! Time elapsed: 15.938574314117432 seconds
