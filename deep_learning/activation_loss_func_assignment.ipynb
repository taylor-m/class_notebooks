# %%
import warnings

warnings.filterwarnings("ignore")

from tensorflow.keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

input_dim = 784 # 28*28
output_dim = nb_classes = 10
batch_size = 128
nb_epoch = 20

X_train = (X_train.reshape(60000, input_dim)).astype('float32')
X_test = (X_test.reshape(10000, input_dim)).astype('float32')
X_test /= 255
X_train /= 255

# %%
from tensorflow.keras.utils import to_categorical

Y_train = to_categorical(y_train, nb_classes)
Y_test = to_categorical(y_test, nb_classes)

# %%
X_train[0].shape
# Out:
# (784,)

# %% [markdown]
# In this assignment, you'll continue working on the MNIST dataset. Train and test the models specified in the tasks below using the MNIST data. You can choose the number of epochs for training, but for the sake of comparison, it's a good idea to start by training for 20 epochs. And remember, you almost always want to use Softmax for the output layer.
#
# To complete this assignment, create a Jupyter Notebook containing your solutions to the following tasks:

# %% [markdown]
# # I. In this task, you'll implement several ANN models with different activation functions. Specifically, do the following:
#
# 1. lement a three-layer ANN model with 128, 64, and 10 neurons in the layers. Use the tanh activation function for each layer.
# 2. lement a three-layer ANN model with 128, 64, and 10 neurons in the layers. Use the sigmoid activation function for each layer.
# 3. lement a three-layer ANN model with 128, 64, and 10 neurons in the layers. Use the ReLU activation function for each layer.
# 4. pare the results of each model. Which activation function performed best?

# %% [markdown]
# ## tanh

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='tanh'))
model.add(Dense(64, input_dim=X_train.shape[1], activation='tanh'))
model.add(Dense(10, input_dim=X_train.shape[1], activation='tanh'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                650
# ...
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, batch_size=batch_size, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.4347 - accuracy: 0.1056
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.9109 - accuracy: 0.0984
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.8842 - accuracy: 0.0975
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.9118 - accuracy: 0.0959
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.8038 - accuracy: 0.0960
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.8878 - accuracy: 0.0965
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.8893 - accuracy: 0.0961
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.8579 - accuracy: 0.0968
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 7.8364 - accuracy: 0.0970
# Epoch 10/20
# ...

# %%
score = model.evaluate(X_test, Y_test, verbose=0)
print('test score:', score[0])
print('test accuracy', score[1])
# Out:
# test score: 7.8285627365112305
# test accuracy 0.0982000008225441

# %% [markdown]
# ## sigmoid

# %%
# model structure
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='sigmoid'))
model.add(Dense(64, input_dim=X_train.shape[1], activation='sigmoid'))
model.add(Dense(10, input_dim=X_train.shape[1], activation='sigmoid'))

# compile
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# fit
model.fit(X_train, Y_train, batch_size=batch_size, epochs=20, verbose=1)

# performance
score = model.evaluate(X_test, Y_test, verbose=0)
print('test score:', score[0])
print('test accuracy', score[1])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 3ms/step - loss: 2.3189 - accuracy: 0.1317
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 2.2461 - accuracy: 0.2404
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 2.1889 - accuracy: 0.4698
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 2.1080 - accuracy: 0.5716
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.9927 - accuracy: 0.6048
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.8318 - accuracy: 0.6472
# Epoch 7/20
# 469/469 [==============================] - 2s 3ms/step - loss: 1.6407 - accuracy: 0.6705
# Epoch 8/20
# 469/469 [==============================] - 2s 3ms/step - loss: 1.4511 - accuracy: 0.6973
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.2857 - accuracy: 0.7336
# Epoch 10/20
# ...

# %% [markdown]
# ## ReLU

# %%
# model structure
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))

# compile
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# fit
model.fit(X_train, Y_train, batch_size=batch_size, epochs=20, verbose=1)

# performance
score = model.evaluate(X_test, Y_test, verbose=0)
print('test score:', score[0])
print('test accuracy', score[1])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0964
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0996
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0964
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0975
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0967
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0995
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0998
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0984
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.0978
# Epoch 10/20
# ...

# %% [markdown]
# > Sigmoid performed the best. ReLU didn't even produce a test score.

# %% [markdown]
# # II. In this task, you'll implement the ANN models specified below. For each, use the hinge loss function as the loss function.
#
# 1. Implement a three-layer ANN model with 128, 64, and 10 neurons in the layers. Use the tanh activation function for each layer.
# 2. Implement a three-layer ANN model with 128, 64, and 10 neurons in the layers. Use the sigmoid activation function for each layer.
# 3. Implement a three-layer ANN model with 128, 64, and 10 neurons in the layers. Use the ReLU activation function for each layer.
# 4. Compare the results of each model with the result of the same model from the previous task. Which loss function performed best?

# %% [markdown]
# ## tanh

# %%
# model structure
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='tanh'))
model.add(Dense(64, input_dim=X_train.shape[1], activation='tanh'))
model.add(Dense(10, input_dim=X_train.shape[1], activation='tanh'))

# compile
model.compile(optimizer='sgd', loss='hinge', metrics=['accuracy'])

# fit
model.fit(X_train, Y_train, batch_size=batch_size, epochs=20, verbose=1)

# performance
score = model.evaluate(X_test, Y_test, verbose=0)
print('test score:', score[0])
print('test accuracy', score[1])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3979 - accuracy: 0.1430
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2104 - accuracy: 0.2264
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2053 - accuracy: 0.2357
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2035 - accuracy: 0.2291
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2026 - accuracy: 0.2236
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2021 - accuracy: 0.2144
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2017 - accuracy: 0.2088
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2015 - accuracy: 0.2009
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2013 - accuracy: 0.1967
# Epoch 10/20
# ...

# %% [markdown]
# ## sigmoid

# %%
# model structure
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='sigmoid'))
model.add(Dense(64, input_dim=X_train.shape[1], activation='sigmoid'))
model.add(Dense(10, input_dim=X_train.shape[1], activation='sigmoid'))

# compile
model.compile(optimizer='sgd', loss='hinge', metrics=['accuracy'])

# fit
model.fit(X_train, Y_train, batch_size=batch_size, epochs=20, verbose=1)

# performance
score = model.evaluate(X_test, Y_test, verbose=0)
print('test score:', score[0])
print('test accuracy', score[1])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.3598 - accuracy: 0.0886
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.1209 - accuracy: 0.0799
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0522 - accuracy: 0.0829
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0310 - accuracy: 0.0825
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0215 - accuracy: 0.0816
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0163 - accuracy: 0.0712
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0130 - accuracy: 0.0642
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0107 - accuracy: 0.0591
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0091 - accuracy: 0.0539
# Epoch 10/20
# ...

# %% [markdown]
# ## ReLU

# %%
# model structure
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))

# compile
model.compile(optimizer='sgd', loss='hinge', metrics=['accuracy'])

# fit
model.fit(X_train, Y_train, batch_size=batch_size, epochs=20, verbose=1)

# performance
score = model.evaluate(X_test, Y_test, verbose=0)
print('test score:', score[0])
print('test accuracy', score[1])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0164 - accuracy: 0.1357
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9988 - accuracy: 0.1070
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9963 - accuracy: 0.1056
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9947 - accuracy: 0.1062
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9941 - accuracy: 0.1052
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9936 - accuracy: 0.1039
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9930 - accuracy: 0.1074
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9930 - accuracy: 0.1056
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9925 - accuracy: 0.1129
# Epoch 10/20
# ...

# %% [markdown]
# >  for the tanh activation function, the hinge loss function had a lower test score but a higher overall accuracy
# > the opposite case for sigmoid
# > the relu and hinge combo performed better
